# %%
import pandas as pd
import matplotlib.pyplot as plt


file_adopted_operating_budget_fy23 = pd.read_csv('./Data/csv/fy23-adopted-operating-budget.csv', encoding='latin1')

file_employee_earnings_report_fy21 = pd.read_csv('./Data/csv/employee-earnings-report-2021.csv', encoding='latin1')
file_employee_earnings_report_fy20 = pd.read_csv('./Data/csv/employee-earnings-report-2020.csv', encoding='latin1')
file_employee_earnings_report_fy19 = pd.read_csv('./Data/csv/employee-earnings-report-2019.csv', encoding='latin1')
file_employee_earnings_report_fy18 = pd.read_csv('./Data/csv/employee-earnings-report-2018.csv', encoding='latin1')
file_employee_earnings_report_fy17 = pd.read_csv('./Data/csv/employee-earnings-report-2017.csv', encoding='latin1')
file_employee_earnings_report_fy16 = pd.read_csv('./Data/csv/employee-earnings-report-2016.csv', encoding='latin1')
file_employee_earnings_report_fy15 = pd.read_csv('./Data/csv/employee-earnings-report-2015.csv', encoding='latin1')
file_employee_earnings_report_fy14 = pd.read_csv('./Data/csv/employee-earnings-report-2014.csv', encoding='latin1')
file_employee_earnings_report_fy13 = pd.read_csv('./Data/csv/employee-earnings-report-2013.csv', encoding='latin1')
file_employee_earnings_report_fy12 = pd.read_csv('./Data/csv/employee-earnings-report-2012.csv', encoding='latin1')
file_employee_earnings_report_fy11 = pd.read_csv('./Data/csv/employee-earnings-report-2011.csv', encoding='latin1')


file_bpd_badges = pd.read_csv('./Data/csv/ALPHa_LISTING_BPD_FRONT_DESK_Badges_included.csv', encoding='latin1')

file_bpd_sworn_job = pd.read_csv('./Data/csv/BPD_SWORN_JOBUPDATE_from_7-1-2017_to_current_date.csv', encoding='latin1')

# fy23-adopted-operating-budget.csv contains
#   8 columns A-H
#   776 rows 1-776
budget_df_uncut = pd.DataFrame(file_adopted_operating_budget_fy23)

badges_df_uncut = pd.DataFrame(file_bpd_badges)
officers_df_uncut = pd.DataFrame(file_bpd_sworn_job)



budget_df_withNA = budget_df_uncut[['Cabinet', 'Dept', 'Program   ', 'Expense Category',
       'FY20 Actual Expense', 'FY21 Actual Expense', 'FY22 Appropriation',
       'FY23 Adopted']]


budget_df = budget_df_withNA.dropna()

earnings21_df = pd.DataFrame(file_employee_earnings_report_fy21)
earnings20_df = pd.DataFrame(file_employee_earnings_report_fy20)
earnings19_df = pd.DataFrame(file_employee_earnings_report_fy19)
earnings18_df = pd.DataFrame(file_employee_earnings_report_fy18)
earnings17_df = pd.DataFrame(file_employee_earnings_report_fy17)
earnings16_df = pd.DataFrame(file_employee_earnings_report_fy16)
earnings15_df = pd.DataFrame(file_employee_earnings_report_fy15)
earnings14_df = pd.DataFrame(file_employee_earnings_report_fy14)
earnings13_df = pd.DataFrame(file_employee_earnings_report_fy13)
earnings12_df = pd.DataFrame(file_employee_earnings_report_fy12)
earnings11_df = pd.DataFrame(file_employee_earnings_report_fy11)

badges_df = badges_df_uncut
officers_df = officers_df_uncut

# %%
print(budget_df.head())

print(earnings21_df.head())
print(earnings20_df.head())
print(earnings19_df.head())
print(earnings17_df.head())
print(earnings16_df.head())
print(earnings15_df.head())
print(earnings14_df.head())
print(earnings13_df.head())
print(earnings12_df.head())
print(earnings11_df.head())



print(badges_df.head())
print(officers_df.head())
# Out:
#                         NAME           DEPARTMENT_NAME  \
# 0            Beckers,Richard  Boston Police Department
# 1      McGowan,Jacqueline M.  Boston Police Department
# 2             Harris,Shawn N  Boston Police Department
# 3          Washington,Walter  Boston Police Department
# 4          Mosley Jr.,Curtis  Boston Police Department
# ...                      ...                       ...
# 22547                    NaN                       NaN
# 22548                    NaN                       NaN
# 22549                    NaN                       NaN
# 22550                    NaN                       NaN
# 22551                    NaN                       NaN
#
#                                 TITLE     REGULAR RETRO         OTHER  \
# 0                      Police Officer         NaN   NaN  1,264,843.63
# 1                      Police Officer         NaN   NaN  1,252,990.81
# 2      Police Offc Comm Serv Offc 3$8   69,772.10   NaN    212,739.48
# ...
